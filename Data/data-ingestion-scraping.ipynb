# %% [markdown]
# ## Data ingestion and scraping
#
# ### How to use this notebook
#
# The goal of this notebook is to download the necessary datasets and structurally prepare them for data cleaning and analysis.
#
# Use this notebook after downloading the datasets from their respective URL. In the case of the Wikipedia data, use the code below to scrape the table from the webpage.

# %% [markdown]
# ### Overview
#
# We will be pulling data from multiple sources that describe various features of a language. This data will be pulled from three main sources, then compiled into one dataset that will be used to train our model.
#
# The datasets and features are as follows:
#
# 1. **Endangered Languages Dataset**
#
#   - *URL:* https://endangeredlanguages.com/userquery/
#   - Number of speakers (numeric- discrete)
#   - Areas and countries where spoken (categorical)
#   - Level of endangerment (categorical)
#
# 2. **Wikipedia list of official languages by country and territory and List of Languages by Speaker Count** $^*$
#
#   - *URL:* https://en.wikipedia.org/wiki/List_of_official_languages_by_country_and_territory
#   - *URL*: https://en.wikipedia.org/wiki/List_of_languages_by_total_number_of_speakers
#   - Recognized as a country's official language by a governement body (binary)
#   - Widely spoken, regional, minority or national language (categorical)
#   - Number of speakers of non-endangered languages (discrete)
#
# 3. **World Bank Indicators**
#   - *URL:* https://data.worldbank.org/indicator?tab=all
#   - Rate of urbanization in countries where it is spoken (numeric- continuous)
#   - Percentage of population using the internet (numeric- continuous)
#
# $^*$ **NOTE:** Under Wikipedia's Creative Commons Attribution-ShareAlike 4.0 International license, you are free to:
#   - Share — copy and redistribute the material in any medium or format for any purpose, even commercially.
#   - Adapt — remix, transform, and build upon the material for any purpose, even commercially.
#   - The licensor cannot revoke these freedoms as long as you follow the license terms.
#
# See more at https://creativecommons.org/licenses/by-sa/4.0/deed.en

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os

# %% [markdown]
# ### Endangered Langauges Dataset

# %%
## Read csv

df1 = pd.read_csv('endangered_languages.csv', header=None)
df1.head()
# Out:
#     0      1      2               3   \
# 0  NaN  index  abbrv   official_name
# 1  1.0   3645    knw            !Xun
# 2  2.0   3956    bpk           'Ôrôê
# 3  3.0   1933    taa  (Lower) Tanana
# 4  4.0   1043    con         A'ingae
#
#                                                   4   \
# 0                                        other_names
# 1  Ju; !Xun (Ekoka); Kung-Ekoka; !Kung; Ekoka-!Xû...
# 2                       Orowe; Boewe; Neukaledonien;
# 3                                                NaN
# 4  Kofane; Cofán; Kofán; A'i; A'ingaé; Colin; Kof...
#
#                                                   5              6   \
# 0                                              level       speakers
# 1  Vulnerable (20 percent certain, based on the e...  14,000-18,000
# 2  Endangered (20 percent certain, based on the e...            590
# 3  Critically Endangered (80 percent certain, bas...             25
# 4  Vulnerable (100 percent certain, based on the ...          1,500
#
#                                                   7   \
# 0                                             root_1
# 1                                              Kx'a
# 2  Austronesian; Malayo-Polynesian; Oceanic; New ...
# 3         Athabaskan-Eyak-Tlingit; Dene (Athabaskan)
# 4                            Isolate; South American
#
#                                                   8       9   \
# 0                                             root_2  root_3
# 1  Southeastern !Xun, Northwestern !Xun, Central ...     NaN
# 2                                                NaN     NaN
# 3                        Minto-Nenana; Salcha; Chena     NaN
# 4                                                NaN     NaN
#
#                                                   10  \
# 0                                             root_4
# 1                                                NaN
# 2                                                NaN
# 3  Tanana is the language of the Lower Tanana riv...
# 4                                                NaN
#
#                              11             12  \
# 0                       country      continent
# 1  South Africa;Namibia;Angola;         Africa
# 2                New Caledonia;        Pacific
# 3                          USA;  North America
# 4             Colombia;Ecuador;  South America
#
#                                                   13
# 0                                           long_lat
# 1  -28.74358,23.983154; -17.560247, 18.050537; -1...
# 2                                  -21.4223,165.4678
# 3  65.157778, -149.37;64.521111, -146.980556;64.5...
# 4                               0.054639, -77.409417

# %%
## Insert column headers
df1 = df1.iloc[:, 1:].reset_index(drop=True)
df1.columns = ['index', 'abbrv', 'official_name', 'other_names', 'level', 'speakers', 'root_1', 'root_2', 'root_3', 
                'root_4', 'country', 'continent', 'long_lat']
df1 = df1[1:]
df1.head()
# Out:
#   index abbrv   official_name  \
# 1  3645   knw            !Xun
# 2  3956   bpk           'Ôrôê
# 3  1933   taa  (Lower) Tanana
# 4  1043   con         A'ingae
# 5  3581   aas           Aasáx
#
#                                          other_names  \
# 1  Ju; !Xun (Ekoka); Kung-Ekoka; !Kung; Ekoka-!Xû...
# 2                       Orowe; Boewe; Neukaledonien;
# 3                                                NaN
# 4  Kofane; Cofán; Kofán; A'i; A'ingaé; Colin; Kof...
# 5  Asax; Asá; Aasá; Assa; Asak; "Ndorobo"; "Dorob...
#
#                                                level       speakers  \
# 1  Vulnerable (20 percent certain, based on the e...  14,000-18,000
# 2  Endangered (20 percent certain, based on the e...            590
# 3  Critically Endangered (80 percent certain, bas...             25
# 4  Vulnerable (100 percent certain, based on the ...          1,500
# 5                                           Dormant               0
#
#                                               root_1  \
# 1                                              Kx'a
# 2  Austronesian; Malayo-Polynesian; Oceanic; New ...
# 3         Athabaskan-Eyak-Tlingit; Dene (Athabaskan)
# 4                            Isolate; South American
# 5             Afro-Asiatic; Cushitic; South Cushitic
#
#                                               root_2 root_3  \
# 1  Southeastern !Xun, Northwestern !Xun, Central ...    NaN
# 2                                                NaN    NaN
# 3                        Minto-Nenana; Salcha; Chena    NaN
# 4                                                NaN    NaN
# 5                                                NaN    NaN
#
#                                               root_4  \
# 1                                                NaN
# 2                                                NaN
# 3  Tanana is the language of the Lower Tanana riv...
# 4                                                NaN
# 5                                                NaN
#
#                         country      continent  \
# 1  South Africa;Namibia;Angola;         Africa
# 2                New Caledonia;        Pacific
# 3                          USA;  North America
# 4             Colombia;Ecuador;  South America
# 5                     Tanzania;         Africa
#
#                                             long_lat
# 1  -28.74358,23.983154; -17.560247, 18.050537; -1...
# 2                                  -21.4223,165.4678
# 3  65.157778, -149.37;64.521111, -146.980556;64.5...
# 4                               0.054639, -77.409417
# 5                                     -5.1948,37.738

# %%
## Save updated csv to repo folder

df1.to_csv('endangered_languages.csv')

# %% [markdown]
# ### Wikipedia Datasets

# %%
## Official language: Scrape from Wikipedia page

# !pip install lxml

## URL of the Wikipedia page
url = "https://en.wikipedia.org/wiki/List_of_official_languages_by_country_and_territory"

## Read all tables from the page
tables = pd.read_html(url)

## Inspect how many tables were found
print(f"Number of tables found: {len(tables)}")

## Example: View the first one (this is usually the main table)
df2 = tables[1]
print(df2.head())
# Out:
# Requirement already satisfied: lxml in /Users/courtneychen/miniforge3/envs/tf/lib/python3.10/site-packages (5.4.0)
# Number of tables found: 9
#          Country/Region  Number of official (including de facto)  \
# 0           Abkhazia[a]                                        2
# 1  Afghanistan[1][2][3]                                        2
# 2            Albania[4]                                        1
# 3            Algeria[5]                                        2
# 4               Andorra                                        1
#
#     Official language(s)                               Regional language(s)  \
# 0         Abkhaz Russian                                                NaN
# 1  Persian (Dari) Pashto  Uzbek[b] Turkmen[b] Pashayi[b] Nuristani[b] Ba...
# 2               Albanian                                                NaN
# 3          Arabic Berber                                                NaN
# 4             Catalan[6]                                                NaN
#
#          Minority language(s)   National language(s)   Widely spoken
# 0                    Georgian                 Abkhaz             NaN
# 1                         NaN  Persian (Dari) Pashto  Persian (Dari)
# 2  Greek Macedonian Aromanian                    NaN         Italian
# 3                         NaN          Arabic Berber          French
# 4   Spanish French Portuguese                    NaN             NaN

# %%
## Save table to csv in repo folder 

df2.to_csv('official_languages.csv')

# %%
## Read new csv

df2 = pd.read_csv('official_languages.csv')
df2.head()
# Out:
#    Unnamed: 0        Country/Region  Number of official (including de facto)  \
# 0           0           Abkhazia[a]                                        2
# 1           1  Afghanistan[1][2][3]                                        2
# 2           2            Albania[4]                                        1
# 3           3            Algeria[5]                                        2
# 4           4               Andorra                                        1
#
#     Official language(s)                               Regional language(s)  \
# 0         Abkhaz Russian                                                NaN
# 1  Persian (Dari) Pashto  Uzbek[b] Turkmen[b] Pashayi[b] Nuristani[b] Ba...
# 2               Albanian                                                NaN
# 3          Arabic Berber                                                NaN
# 4             Catalan[6]                                                NaN
#
#          Minority language(s)   National language(s)   Widely spoken
# 0                    Georgian                 Abkhaz             NaN
# 1                         NaN  Persian (Dari) Pashto  Persian (Dari)
# 2  Greek Macedonian Aromanian                    NaN         Italian
# 3                         NaN          Arabic Berber          French
# 4   Spanish French Portuguese                    NaN             NaN

# %%
## Number of Speakers: Scrape from Wikipedia page

# !pip install lxml

## URL of the Wikipedia page
url = "https://en.wikipedia.org/wiki/List_of_languages_by_total_number_of_speakers"

## Read all tables from the page
tables_2 = pd.read_html(url)

## Inspect how many tables were found
print(f"Number of tables found: {len(tables_2)}")

## Example: View the first one (this is usually the main table)
df5 = tables_2[0]
print(df5.head())
# Out:
# Requirement already satisfied: lxml in /Users/courtneychen/miniforge3/envs/tf/lib/python3.10/site-packages (5.4.0)
# Number of tables found: 7
#                                             Language         Family  \
#                                             Language         Family
# 0                   English (excl. creole languages)  Indo-European
# 1  Mandarin Chinese (incl. Standard Chinese but e...   Sino-Tibetan
# 2                                 Hindi (excl. Urdu)  Indo-European
# 3                   Spanish (excl. creole languages)  Indo-European
# 4            Modern Standard Arabic (excl. dialects)   Afro-Asiatic
#
#        Branch Numbers of speakers (millions)                        \
#        Branch           First- language (L1) Second- language (L2)
# 0    Germanic                            390                  1138
# 1     Sinitic                            990                   194
# 2  Indo-Aryan                            345                   264
# 3     Romance                            484                    74
# 4     Semitic                           0[a]                   335
#
#
#   Total (L1+L2)
# 0          1528
# 1          1184
# 2           609
# 3           558
# 4           335

# %%
## Save table to csv in repo folder 

df5.to_csv('speaker_count.csv')

# %%
## Read new csv

df5 = pd.read_csv('speaker_count.csv')
df5.head()
# Out:
#    Unnamed: 0                                           Language  \
# 0         NaN                                           Language
# 1         0.0                   English (excl. creole languages)
# 2         1.0  Mandarin Chinese (incl. Standard Chinese but e...
# 3         2.0                                 Hindi (excl. Urdu)
# 4         3.0                   Spanish (excl. creole languages)
#
#           Family      Branch Numbers of speakers (millions)  \
# 0         Family      Branch           First- language (L1)
# 1  Indo-European    Germanic                            390
# 2   Sino-Tibetan     Sinitic                            990
# 3  Indo-European  Indo-Aryan                            345
# 4  Indo-European     Romance                            484
#
#   Numbers of speakers (millions).1 Numbers of speakers (millions).2
# 0            Second- language (L2)                    Total (L1+L2)
# 1                             1138                             1528
# 2                              194                             1184
# 3                              264                              609
# 4                               74                              558

# %% [markdown]
# ### World Bank Indicators: urban development

# %%
## Read csv- skip rows with extra comments

df3 = pd.read_csv('wb_urban.csv', skiprows= 3)
df3.head()
# Out:
#    2   5               Albania  ALB  Urban population (% of total population)  \
# 0  3   6               Andorra  AND  Urban population (% of total population)
# 1  4   7            Arab World  ARB  Urban population (% of total population)
# 2  5   8  United Arab Emirates  ARE  Urban population (% of total population)
# 3  6   9             Argentina  ARG  Urban population (% of total population)
# 4  7  10               Armenia  ARM  Urban population (% of total population)
#
#    SP.URB.TOTL.IN.ZS     30.705     30.943     31.015     31.086  ...  \
# 0  SP.URB.TOTL.IN.ZS  58.450000  60.983000  63.462000  65.872000  ...
# 1  SP.URB.TOTL.IN.ZS  31.010536  31.727163  32.451442  33.194309  ...
# 2  SP.URB.TOTL.IN.ZS  73.500000  74.383000  75.248000  76.093000  ...
# 3  SP.URB.TOTL.IN.ZS  73.611000  74.217000  74.767000  75.309000  ...
# 4  SP.URB.TOTL.IN.ZS  51.275000  52.147000  53.019000  53.889000  ...
#
#       58.421     59.383     60.319     61.229     62.112     62.969  \
# 0  88.248000  88.150000  88.062000  87.984000  87.916000  87.858000
# 1  57.653103  57.862747  58.010484  58.204542  58.496674  58.662927
# 2  85.965000  86.248000  86.522000  86.789000  87.048000  87.299000
# 3  91.627000  91.749000  91.870000  91.991000  92.111000  92.229000
# 4  63.082000  63.103000  63.149000  63.219000  63.313000  63.431000
#
#       63.799     64.603  Unnamed: 70  Unnamed: 71
# 0  87.811000  87.774000          NaN          NaN
# 1  59.054267  59.443854          NaN          NaN
# 2  87.543000  87.779000          NaN          NaN
# 3  92.347000  92.463000          NaN          NaN
# 4  63.573000  63.739000          NaN          NaN
#
# [5 rows x 72 columns]

# %%
## Save updated csv to repo folder

df3.to_csv('wb_urban.csv')

# %% [markdown]
# ### World Bank Indicators: internet users

# %%
## Read csv- skip rows with extra comments

df4 = pd.read_csv('wb_internet.csv', skiprows= 3)
df4.head()
# Out:
#    2   5               Albania  ALB  \
# 0  3   6               Andorra  AND
# 1  4   7            Arab World  ARB
# 2  5   8  United Arab Emirates  ARE
# 3  6   9             Argentina  ARG
# 4  7  10               Armenia  ARM
#
#    Individuals using the Internet (% of population)  IT.NET.USER.ZS  \
# 0  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 1  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 2  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 3  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 4  Individuals using the Internet (% of population)  IT.NET.USER.ZS
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  59.6  62.4  65.4  \
# 0         NaN         NaN         NaN         NaN  ...  89.7  91.6   NaN
# 1         NaN         NaN         NaN         NaN  ...   NaN   NaN   NaN
# 2         NaN         NaN         NaN         NaN  ...  90.6  94.8  98.5
# 3         NaN         NaN         NaN         NaN  ...  71.0  74.3  77.7
# 4         NaN         NaN         NaN         NaN  ...  64.3  64.7  68.2
#
#    68.6   72.2   79.3   82.6   83.1  Unnamed: 70  Unnamed: 71
# 0  90.7   93.2   93.9   94.5   95.4          NaN          NaN
# 1   NaN    NaN    NaN    NaN    NaN          NaN          NaN
# 2  99.2  100.0  100.0  100.0  100.0          NaN          NaN
# 3  79.9   85.5   87.2   88.4   89.2          NaN          NaN
# 4  66.5   76.5   78.6   77.0   80.0          NaN          NaN
#
# [5 rows x 72 columns]

# %%
## Save updated csv to repo folder

df4.to_csv('wb_internet.csv')

# %% [markdown]
# ###
